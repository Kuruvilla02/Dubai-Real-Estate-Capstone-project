# %%
import pandas as pd
import numpy as np

# %%
dataset1 = "Datasets/dataframeAreasWithALLCoord.csv"
dataset2 = "Datasets/dataframeProjectWithALLCoord.csv"
dataset3 = "Datasets/transactions-2023-07-02.csv"

# %%
df1 = pd.read_csv(dataset1)
df2 = pd.read_csv(dataset2)
df3 = pd.read_csv(dataset3)

# %%
df1.head()
# Out:
#                       Area  Latitude_Area  Longitude_Area
# 0             BUSINESS BAY      25.189427       55.264819
# 1                  Al Wasl      25.195933       55.255737
# 2    JUMEIRAH LAKES TOWERS      25.072383       55.143743
# 3  JUMEIRAH VILLAGE CIRCLE      25.071164       55.210889
# 4      DUBAI CREEK HARBOUR      25.197978       55.360380

# %%
df2.head()
# Out:
#             Project  Latitude_Project  Longitude_Project
# 0      AYKON CITY 3          25.11072           55.38869
# 1              Fern          24.99426           55.16346
# 2    SEVEN CITY JLT          25.07052           55.14381
# 3  Binghatti Corner          25.11000           55.20418
# 4        CREEK EDGE          25.20809           55.31542

# %%
df3.head()
# Out:
#   Transaction Number     Transaction Date Transaction Type  \
# 0         102-1-2023  2023-01-02 07:25:49            Sales
# 1        102-10-2023  2023-01-02 08:06:49            Sales
# 2       102-100-2023  2023-01-02 09:01:22            Sales
# 3      102-1000-2023  2023-01-05 13:26:06            Sales
# 4     102-10000-2023  2023-03-01 16:02:19            Sales
#
#       Transaction sub type Registration type Is Free Hold?        Usage  \
# 0  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 2  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 3  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 4  Sell - Pre registration          Off-Plan     Free Hold  Residential
#
#                       Area Property Type Property Sub Type  ...  \
# 0             BUSINESS BAY          Unit              Flat  ...
# 1             BUSINESS BAY          Unit              Flat  ...
# 2                  Al Wasl          Unit              Flat  ...
# 3    JUMEIRAH LAKES TOWERS          Unit              Flat  ...
# 4  JUMEIRAH VILLAGE CIRCLE          Unit              Flat  ...
#
#    Property Size (sq.m)  Room(s)  Parking               Nearest Metro  \
# 0                105.75    2 B/R        1  Business Bay Metro Station
# 1                 52.29   Studio        1  Business Bay Metro Station
# 2                161.32    2 B/R        1                         NaN
# 3                 99.64    2 B/R        1            Damac Properties
# 4                 63.95    1 B/R        1         Dubai Internet City
#
#   Nearest Mall              Nearest Landmark No. of Buyer No. of Seller  \
# 0   Dubai Mall                Downtown Dubai            1             1
# 1   Dubai Mall                Downtown Dubai            1             1
# 2          NaN                           NaN            1             1
# 3  Marina Mall                  Burj Al Arab            1             1
# 4  Marina Mall  Sports City Swimming Academy            1             1
#
#    Master Project           Project
# 0             NaN      AYKON CITY 3
# 1             NaN      AYKON CITY 3
# 2             NaN              Fern
# 3             NaN    SEVEN CITY JLT
# 4             NaN  Binghatti Corner
#
# [5 rows x 22 columns]

# %%
df = pd.merge(df3, df1, on='Area', how='left')
df= pd.merge(df3, df2, on='Project', how='left')

# %%
df.head()
# Out:
#   Transaction Number     Transaction Date Transaction Type  \
# 0         102-1-2023  2023-01-02 07:25:49            Sales
# 1        102-10-2023  2023-01-02 08:06:49            Sales
# 2       102-100-2023  2023-01-02 09:01:22            Sales
# 3      102-1000-2023  2023-01-05 13:26:06            Sales
# 4     102-10000-2023  2023-03-01 16:02:19            Sales
#
#       Transaction sub type Registration type Is Free Hold?        Usage  \
# 0  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 2  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 3  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 4  Sell - Pre registration          Off-Plan     Free Hold  Residential
#
#                       Area Property Type Property Sub Type  ...  Parking  \
# 0             BUSINESS BAY          Unit              Flat  ...        1
# 1             BUSINESS BAY          Unit              Flat  ...        1
# 2                  Al Wasl          Unit              Flat  ...        1
# 3    JUMEIRAH LAKES TOWERS          Unit              Flat  ...        1
# 4  JUMEIRAH VILLAGE CIRCLE          Unit              Flat  ...        1
#
#                 Nearest Metro  Nearest Mall              Nearest Landmark  \
# 0  Business Bay Metro Station    Dubai Mall                Downtown Dubai
# 1  Business Bay Metro Station    Dubai Mall                Downtown Dubai
# 2                         NaN           NaN                           NaN
# 3            Damac Properties   Marina Mall                  Burj Al Arab
# 4         Dubai Internet City   Marina Mall  Sports City Swimming Academy
#
#   No. of Buyer No. of Seller Master Project           Project  \
# 0            1             1            NaN      AYKON CITY 3
# 1            1             1            NaN      AYKON CITY 3
# 2            1             1            NaN              Fern
# 3            1             1            NaN    SEVEN CITY JLT
# 4            1             1            NaN  Binghatti Corner
#
#    Latitude_Project  Longitude_Project
# 0          25.11072           55.38869
# 1          25.11072           55.38869
# 2          24.99426           55.16346
# 3          25.07052           55.14381
# 4          25.11000           55.20418
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (81601, 24)

# %%
df.columns
# Out:
# Index(['Transaction Number', 'Transaction Date', 'Transaction Type',
#        'Transaction sub type', 'Registration type', 'Is Free Hold?', 'Usage',
#        'Area', 'Property Type', 'Property Sub Type', 'Amount',
#        'Transaction Size (sq.m)', 'Property Size (sq.m)', 'Room(s)', 'Parking',
#        'Nearest Metro', 'Nearest Mall', 'Nearest Landmark', 'No. of Buyer',
#        'No. of Seller', 'Master Project', 'Project', 'Latitude_Project',
#        'Longitude_Project'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Transaction Number             0
# Transaction Date               0
# Transaction Type               0
# Transaction sub type           0
# Registration type              0
# Is Free Hold?                  0
# Usage                          0
# Area                           0
# Property Type                  0
# Property Sub Type           1159
# Amount                         0
# Transaction Size (sq.m)      483
# Property Size (sq.m)           0
# Room(s)                    15019
# Parking                    23764
# Nearest Metro              27042
# Nearest Mall               27101
# Nearest Landmark           17716
# No. of Buyer                   0
# No. of Seller                  0
# Master Project             81487
# Project                    17723
# Latitude_Project               0
# Longitude_Project              0
# dtype: int64

# %%
df[df['Property Sub Type'] == 'Land'][['Property Type', 'Property Sub Type']].shape
# Out:
# (399, 2)

# %%
df4=df[df['Property Type'] == 'Land']

# %%
df4
# Out:
#       Transaction Number     Transaction Date Transaction Type  \
# 27851      102-7615-2023  2023-02-16 14:44:33            Sales
# 27852      102-7616-2023  2023-02-16 14:45:20            Sales
# 27853      102-7617-2023  2023-02-16 14:45:42            Sales
# 27855      102-7619-2023  2023-02-16 14:46:14            Sales
# 27858      102-7621-2023  2023-02-16 14:47:04            Sales
# ...                  ...                  ...              ...
# 81435         9-858-2023  2023-02-22 10:05:23            Gifts
# 81466         9-886-2023  2023-02-22 10:54:30            Gifts
# 81470          9-89-2023  2023-01-06 11:19:08            Gifts
# 81546          9-96-2023  2023-01-09 10:55:52            Gifts
# 81557          9-97-2023  2023-01-09 11:56:30            Gifts
#
#           Transaction sub type Registration type  Is Free Hold?        Usage  \
# 27851  Sell - Pre registration          Off-Plan      Free Hold  Residential
# 27852  Sell - Pre registration          Off-Plan      Free Hold  Residential
# 27853  Sell - Pre registration          Off-Plan      Free Hold  Residential
# 27855  Sell - Pre registration          Off-Plan      Free Hold  Residential
# 27858  Sell - Pre registration          Off-Plan      Free Hold  Residential
# ...                        ...               ...            ...          ...
# 81435                    Grant             Ready  Non Free Hold  Residential
# 81466                    Grant             Ready      Free Hold  Residential
# 81470                    Grant             Ready      Free Hold  Residential
# 81546                    Grant             Ready      Free Hold   Commercial
# 81557                    Grant             Ready  Non Free Hold  Residential
#
#                     Area Property Type Property Sub Type  ...  Parking  \
# 27851  Madinat Al Mataar          Land           Airport  ...      NaN
# 27852  Madinat Al Mataar          Land           Airport  ...      NaN
# 27853  Madinat Al Mataar          Land           Airport  ...      NaN
# 27855  Madinat Al Mataar          Land           Airport  ...      NaN
# 27858  Madinat Al Mataar          Land           Airport  ...      NaN
# ...                  ...           ...               ...  ...      ...
# 81435        Um Al Sheif          Land       Residential  ...      NaN
# 81466          AL FURJAN          Land       Residential  ...      NaN
# 81470        DUBAI HILLS          Land       Residential  ...      NaN
# 81546      PALM JUMEIRAH          Land        Commercial  ...      NaN
# 81557            Al Bada          Land       Residential  ...      NaN
#
#                             Nearest Metro          Nearest Mall  \
# 27851                                 NaN                   NaN
# 27852                                 NaN                   NaN
# 27853                                 NaN                   NaN
# 27855                                 NaN                   NaN
# 27858                                 NaN                   NaN
# ...                                   ...                   ...
# 81435  First Abu Dhabi Bank Metro Station  Mall of the Emirates
# 81466           Ibn Battuta Metro Station    Ibn-e-Battuta Mall
# 81470  First Abu Dhabi Bank Metro Station  Mall of the Emirates
# 81546                           Al Sufouh  Mall of the Emirates
# 81557       Emirates Towers Metro Station            Dubai Mall
#
#       Nearest Landmark No. of Buyer No. of Seller Master Project      Project  \
# 27851              NaN            2             1            NaN  South Bay 1
# 27852              NaN            3             1            NaN  South Bay 1
# 27853              NaN            2             1            NaN  South Bay 1
# 27855              NaN            1             1            NaN  South Bay 1
# 27858              NaN            2             1            NaN  South Bay 1
# ...                ...          ...           ...            ...          ...
# 81435     Burj Al Arab            0             0            NaN          NaN
# 81466   Expo 2020 Site            0             0            NaN          NaN
# 81470       Motor City            0             0            NaN      Sidra 2
# 81546     Burj Al Arab            0             0            NaN          NaN
# 81557     Burj Khalifa            0             0            NaN          NaN
#
#        Latitude_Project  Longitude_Project
# 27851          24.95896           55.09458
# 27852          24.95896           55.09458
# 27853          24.95896           55.09458
# 27855          24.95896           55.09458
# 27858          24.95896           55.09458
# ...                 ...                ...
# 81435          25.10757           55.24194
# 81466          25.10757           55.24194
# 81470          25.09923           55.24839
# 81546          25.10757           55.24194
# 81557          25.10757           55.24194
#
# [14264 rows x 24 columns]
