# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset1 = "Datasets/dataframeAreasWithALLCoord.csv"
dataset2 = "Datasets/dataframeProjectWithALLCoord.csv"
dataset3 = "Datasets/transactions-2023-07-02.csv"

# %%
df1 = pd.read_csv(dataset1)
df2 = pd.read_csv(dataset2)
df3 = pd.read_csv(dataset3)

# %%
df1.head()
# Out:
#                       Area  Latitude_Area  Longitude_Area
# 0             BUSINESS BAY      25.189427       55.264819
# 1                  Al Wasl      25.195933       55.255737
# 2    JUMEIRAH LAKES TOWERS      25.072383       55.143743
# 3  JUMEIRAH VILLAGE CIRCLE      25.071164       55.210889
# 4      DUBAI CREEK HARBOUR      25.197978       55.360380

# %%
df2.head()
# Out:
#             Project  Latitude_Project  Longitude_Project
# 0      AYKON CITY 3          25.11072           55.38869
# 1              Fern          24.99426           55.16346
# 2    SEVEN CITY JLT          25.07052           55.14381
# 3  Binghatti Corner          25.11000           55.20418
# 4        CREEK EDGE          25.20809           55.31542

# %%
df3.head()
# Out:
#   Transaction Number     Transaction Date Transaction Type  \
# 0         102-1-2023  2023-01-02 07:25:49            Sales
# 1        102-10-2023  2023-01-02 08:06:49            Sales
# 2       102-100-2023  2023-01-02 09:01:22            Sales
# 3      102-1000-2023  2023-01-05 13:26:06            Sales
# 4     102-10000-2023  2023-03-01 16:02:19            Sales
#
#       Transaction sub type Registration type Is Free Hold?        Usage  \
# 0  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 2  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 3  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 4  Sell - Pre registration          Off-Plan     Free Hold  Residential
#
#                       Area Property Type Property Sub Type  ...  \
# 0             BUSINESS BAY          Unit              Flat  ...
# ...

# %%
df = pd.merge(df3, df1, on='Area', how='left')
df= pd.merge(df3, df2, on='Project', how='left')

# %%
df.head()
# Out:
#   Transaction Number     Transaction Date Transaction Type  \
# 0         102-1-2023  2023-01-02 07:25:49            Sales
# 1        102-10-2023  2023-01-02 08:06:49            Sales
# 2       102-100-2023  2023-01-02 09:01:22            Sales
# 3      102-1000-2023  2023-01-05 13:26:06            Sales
# 4     102-10000-2023  2023-03-01 16:02:19            Sales
#
#       Transaction sub type Registration type Is Free Hold?        Usage  \
# 0  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 2  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 3  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 4  Sell - Pre registration          Off-Plan     Free Hold  Residential
#
#                       Area Property Type Property Sub Type  ...  Parking  \
# 0             BUSINESS BAY          Unit              Flat  ...        1
# ...

# %%
df.shape
# Out:
# (81601, 24)

# %%
df.columns
# Out:
# Index(['Transaction Number', 'Transaction Date', 'Transaction Type',
#        'Transaction sub type', 'Registration type', 'Is Free Hold?', 'Usage',
#        'Area', 'Property Type', 'Property Sub Type', 'Amount',
#        'Transaction Size (sq.m)', 'Property Size (sq.m)', 'Room(s)', 'Parking',
#        'Nearest Metro', 'Nearest Mall', 'Nearest Landmark', 'No. of Buyer',
#        'No. of Seller', 'Master Project', 'Project', 'Latitude_Project',
#        'Longitude_Project'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# Transaction Number             0
# Transaction Date               0
# Transaction Type               0
# Transaction sub type           0
# Registration type              0
# Is Free Hold?                  0
# Usage                          0
# Area                           0
# Property Type                  0
# Property Sub Type           1159
# Amount                         0
# Transaction Size (sq.m)      483
# Property Size (sq.m)           0
# Room(s)                    15019
# Parking                    23764
# Nearest Metro              27042
# Nearest Mall               27101
# Nearest Landmark           17716
# No. of Buyer                   0
# No. of Seller                  0
# Master Project             81487
# Project                    17723
# Latitude_Project               0
# Longitude_Project              0
# dtype: int64

# %%
df['Room(s)']
# Out:
# 0         2 B/R
# 1        Studio
# 2         2 B/R
# 3         2 B/R
# 4         1 B/R
#           ...
# 81596     2 B/R
# 81597     2 B/R
# 81598     1 B/R
# 81599     1 B/R
# 81600     1 B/R
# Name: Room(s), Length: 81601, dtype: object

# %%
pd.set_option('display.max_columns', None)

# %%
df5 = df['Room(s)'].isnull()
df[df5].head(5)
# Out:
#      Transaction Number     Transaction Date Transaction Type  \
# 92       102-10081-2023  2023-03-02 07:58:30            Sales
# 559      102-10510-2023  2023-03-05 15:11:10            Sales
# 1531     102-11402-2023  2023-03-08 12:18:41            Sales
# 1570     102-11439-2023  2023-03-08 14:14:59            Sales
# 1679     102-11537-2023  2023-03-09 07:30:42            Sales
#
#          Transaction sub type Registration type Is Free Hold?        Usage  \
# 92    Sell - Pre registration          Off-Plan     Free Hold  Residential
# 559   Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1531  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1570  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1679  Sell - Pre registration          Off-Plan     Free Hold  Residential
#
#                  Area Property Type Property Sub Type     Amount  \
# 92    SOBHA HEARTLAND          Unit              Shop  1133594.0
# ...

# %%
df5.shape
# Out:
# (81601,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81601 entries, 0 to 81600
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Transaction Number       81601 non-null  object
#  1   Transaction Date         81601 non-null  object
#  2   Transaction Type         81601 non-null  object
#  3   Transaction sub type     81601 non-null  object
#  4   Registration type        81601 non-null  object
#  5   Is Free Hold?            81601 non-null  object
#  6   Usage                    81601 non-null  object
#  7   Area                     81601 non-null  object
#  8   Property Type            81601 non-null  object
#  9   Property Sub Type        80442 non-null  object
#  10  Amount                   81601 non-null  float64
#  11  Transaction Size (sq.m)  81118 non-null  float64
#  12  Property Size (sq.m)     81601 non-null  float64
#  13  Room(s)                  66582 non-null  object
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std       min  \
# Amount                   81601.0  3.124265e+06  2.145941e+07  57.00000
# Transaction Size (sq.m)  81118.0  7.265520e+02  6.925276e+04   0.00000
# Property Size (sq.m)     81601.0  7.489233e+02  6.909542e+04   6.43000
# No. of Buyer             81601.0  8.749035e-01  6.341489e-01   0.00000
# No. of Seller            81601.0  8.227473e-01  7.374291e-01   0.00000
# Latitude_Project         81601.0  2.510985e+01  7.387628e-02  24.30566
# Longitude_Project        81601.0  5.523669e+01  7.856565e-02  54.60719
#
#                                   25%           50%           75%  \
# Amount                   725000.00000  1.440000e+06  2.596020e+06
# Transaction Size (sq.m)      67.88000  1.061500e+02  1.865850e+02
# Property Size (sq.m)         68.51000  1.077600e+02  1.882500e+02
# No. of Buyer                  0.00000  1.000000e+00  1.000000e+00
# No. of Seller                 0.00000  1.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ### 1. Distribution of different transaction types over the entire dataset.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Transaction Type', data=df)
plt.title('Distribution of Transaction Types')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 2. Types of properties involved in transactions and their frequency.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Property Type', data=df, hue='Transaction Type')
plt.title('Transaction Types by Property Type')
plt.xlabel('Property Type')
plt.ylabel('Count')
plt.legend(title='Transaction Type')
plt.show()
